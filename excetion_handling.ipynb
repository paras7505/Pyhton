# %% [markdown]
# Exception Handling
# Types of errors
#
# Combile Time / Syntax Error,
# Logical Error,
# Run Time,

# %% [markdown]
# compile error

# %%
print(x
# Out:
#   File "<ipython-input-1-688950385000>", line 1
#     print(x
#            ^
# SyntaxError: incomplete input

# %%
print("hello')
# Out:
#   File "<ipython-input-2-ebeda6125e45>", line 1
#     print("hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
for i in range(10)
    print(i)
# Out:
#   File "<ipython-input-3-7a8a49ad5eea>", line 1
#     for i in range(10)
#                       ^
# SyntaxError: expected ':'

# %% [markdown]
# **Logical** **Error**

# %%
def sumoftwo(a,b):
  return a*b
sumoftwo(2,2)
sumoftwo(2,3) # this is logical error
# Out:
# 6

# %%
if a>b:
  print("a is greater")
else:
  print("b is greater")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd81628f6b4e> in <cell line: 1>()
# ----> 1 if a>b:
#       2   print("a is greater")
#       3 else:
#       4   print("b is greater")
#       5
#
# NameError: name 'a' is not defined

# %% [markdown]
# **Run time Error / Exceptions**

# %%
dvideByZero = 100 / 0
print(divideByZero)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-d53870ab7996> in <cell line: 1>()
# ----> 1 dvideByZero = 100 / 0
#       2 print(divideByZero)
#
# ZeroDivisionError: division by zero

# %%
x= [1,2,3]
print(x[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-a24c91e84aa9> in <cell line: 2>()
#       1 x= [1,2,3]
# ----> 2 print(x[4])
#
# IndexError: list index out of range

# %%
import dsfd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-293531327388> in <cell line: 1>()
# ----> 1 import dsfd
#
# ModuleNotFoundError: No module named 'dsfd'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
d = {
    'name': 'paras pandey'
}

print(d['chapter'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-14e9de0881b3> in <cell line: 5>()
#       3 }
#       4
# ----> 5 print(d['chapter'])
#
# KeyError: 'chapter'

# %% [markdown]
# **Raising an Exception**

# %%
x = -33
if x>0:
  print("my number is :", x)
else:
  raise ValueError("only positive numbers are allowed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-08d4202fb5f0> in <cell line: 2>()
#       3   print("my number is :", x)
#       4 else:
# ----> 5   raise ValueError("only positive numbers are allowed")
#
# ValueError: only positive numbers are allowed

# %%
x = 11

if type(x) is not int:
  raise ValueError("the value is not integer")

# %% [markdown]
# **assertion error** **exception**

# %%
x = 'sdf'
assert type(x) is int, "assertion error"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-c0587a7fd176> in <cell line: 2>()
#       1 x = 'sdf'
# ----> 2 assert type(x) is int, "assertion error"
#
# AssertionError: assertion error
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-c0587a7fd176> in <cell line: 2>()
#       1 x = 'sdf'
# ----> 2 assert type(x) is int, "assertion error"
#
# AssertionError: assertion error

# %%
a = 1
b = 0

assert b!= 0 , "raise the error "

print(a/b)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-0ebde0e4291e> in <cell line: 4>()
#       2 b = 0
#       3
# ----> 4 assert b!= 0 , "raise the error "
#       5
#       6 print(a/b)
#
# AssertionError: raise the error

# %% [markdown]
# handling pyhton error

# %%
# in pyhton
try:
  print(x)
except:
  print("an exception occured")


# in other languages

try:
  print(x)
catch:
  print("an exception occured")
# Out:
# sdf

# %%
def checkval():
  x = 0
  if x!=0:
    print("the number is non zero")
  else:
   raise ValueError("the number is zero")

try:
  checkval()
except:
  print("you got an error")
# Out:
# you got an error

# %%
def checkval():
  x = -30
  if x > 0:
    print("the number is greater")
  else:
    raise valueError("the input is not valid ")

try:
  checkval()
except:
  print("you got an error")
# Out:
# you got an error

# %%
 b = 4
 try:
  assert b==0 , "assertion error"
except:
  print("you got an error")
# Out:
# you got an error

# %%
c = 4
try:
  assert  not c!=0 , "assertion error"
except:
  print("you got an error")

# %%
b = 0
try:
  assert  b!=0 , "assertion error"
except ValueError:
  print("this is value Error")
except AssertionError:
  print("this is assertion error")
except Exception:
  print("this is exception")
except:
  print("any anther error")
# Out:
# this is assertion error

# %%
try:
  f = open("file.txt" , "r")
  print("file open")
except FileNotFoundError:
  print("file not found")
finally:
  print("file closed")
# Out:
# file not found
# file closed
